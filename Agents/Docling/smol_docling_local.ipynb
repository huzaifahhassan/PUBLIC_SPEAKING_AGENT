# %%
import os
from dotenv import load_dotenv
from huggingface_hub import hf_hub_download

load_dotenv()
HUGGING_FACE_API_KEY=os.environ["HUGGING_FACE_API_KEY"]

# %%
# Load model directly
from transformers import AutoProcessor, AutoModelForImageTextToText

processor = AutoProcessor.from_pretrained("ds4sd/SmolDocling-256M-preview")
model = AutoModelForImageTextToText.from_pretrained("ds4sd/SmolDocling-256M-preview")

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-text-to-text", model=model)
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image", "url": "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/p-blog/candy.JPG"},
            {"type": "text", "text": "What animal is on the candy?"}
        ]
    },
]

pipe(text=messages)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Use a pipeline as a high-level helper
#       2 from transformers import pipeline
# ----> 4 pipe = pipeline("image-text-to-text", model=model)
#       5 messages = [
#       6     {
#       7         "role": "user",
#    (...)
#      12     },
#      13 ]
#      15 pipe(text=messages)
#
# File c:\Users\huzin\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\__init__.py:1136, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1133         processor = config
#    1134     else:
#    1135         # Impossible to guess what is the right processor here
# -> 1136         raise Exception(
#    1137             "Impossible to guess which processor to use. "
#    1138             "Please provide a processor instance or a path/identifier "
#    1139             "to a processor."
#    1140         )
#    1142 # Instantiate processor if needed
#    1143 if isinstance(processor, (str, tuple)):
#
# Exception: Impossible to guess which processor to use. Please provide a processor instance or a path/identifier to a processor.
